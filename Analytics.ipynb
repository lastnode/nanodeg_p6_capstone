# %%
import pandas as pd
import pyarrow
import pandasql as ps
import glob

# %% [markdown]
# ## Chess.com

# %%
files = glob.glob('output_data/fact/chessdotcom/moves9/*.parquet')
df_chesscom = pd.concat([pd.read_parquet(fp) for fp in files])

# %%
#pd.set_option('display.max_rows', None)

# %%
df_chesscom
# Out:
#            game_end_time game_end_date time_class  rated     white_username  \
# 0    2020-10-08 02:38:27    2020-10-08      blitz   True  VitaliyBernadskiy
# 1    2020-10-08 02:45:07    2020-10-08      blitz   True   Farrukh_Amonatov
# 2    2020-10-08 02:50:36    2020-10-08      blitz   True  VitaliyBernadskiy
# 3    2020-10-08 02:54:29    2020-10-08      blitz   True   Farrukh_Amonatov
# 4    2020-10-08 02:55:52    2020-10-08      blitz   True               KD64
# ..                   ...           ...        ...    ...                ...
# 707  2021-01-23 04:25:38    2021-01-23      blitz   True         MrTeifel79
# 708  2021-01-23 04:28:14    2021-01-23      blitz   True      FlorianHandke
# 709  2021-01-23 04:31:41    2021-01-23      blitz   True           fyall777
# 710  2021-01-23 04:33:02    2021-01-23      blitz   True   Farrukh_Amonatov
# 711  2021-01-23 04:34:59    2021-01-23      blitz   True      FlorianHandke
#
#      white_rating     black_username  black_rating winner  \
# 0            2788   Farrukh_Amonatov          2755  white
# 1            2764  VitaliyBernadskiy          2779  white
# 2            2771   Farrukh_Amonatov          2772  black
# 3            2780  VitaliyBernadskiy          2763  white
# 4            2510           fyall777          2495  white
# ..            ...                ...           ...    ...
# 707          2350           fyall777          2505  black
# 708          2627          Skagoogle          2669  black
# 709          2497           dumpsack          2534  black
# 710          2903            eljanov          2884   None
# 711          2632           Alos2006          2506  white
#
#                              termination  \
# 0          VitaliyBernadskiy won on time
# 1    Farrukh_Amonatov won by resignation
# 2    Farrukh_Amonatov won by resignation
# 3    Farrukh_Amonatov won by resignation
# 4                       KD64 won on time
# ..                                   ...
# 707          fyall777 won by resignation
# 708                Skagoogle won on time
# 709                 dumpsack won on time
# 710              Game drawn by agreement
# 711            FlorianHandke won on time
#
#                                                opening  \
# 0            Sicilian Defense Grand Prix Attack 3...d6
# 1    Scotch Game Classical Variation 5.Be3 Qf6 6.c3...
# 2                Sicilian Defense Deferred Wing Gambit
# 3    Scotch Game Schmidt Mieses Variation 6...Qe7 7...
# 4        Queens Pawn Opening Accelerated London System
# ..                                                 ...
# 707  Nimzowitsch Larsen Attack Modern Variation 2.B...
# 708          Sicilian Defense Open Classical Variation
# 709                   Slav Defense Modern Line 3...Nf6
# 710  Ruy Lopez Opening Berlin lHermet Berlin Wall D...
# 711  Sicilian Defense Kan Modern Polugaevsky Variat...
#
#                                                  moves     platform
# 0    1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02:5...  chessdotcom
# 1    1. e4 {[%clk 0:02:59.9]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 2    1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02:5...  chessdotcom
# 3    1. e4 {[%clk 0:02:59.9]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 4    1. d4 {[%clk 0:02:59.9]} 1... d5 {[%clk 0:02:5...  chessdotcom
# ..                                                 ...          ...
# 707  1. b3 {[%clk 0:02:59.3]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 708  1. e4 {[%clk 0:02:59.3]} 1... c5 {[%clk 0:02:5...  chessdotcom
# 709  1. d4 {[%clk 0:02:59.9]} 1... Nf6 {[%clk 0:02:...  chessdotcom
# 710  1. e4 {[%clk 0:03:00]} 1... e5 {[%clk 0:02:59]...  chessdotcom
# 711  1. e4 {[%clk 0:03:00]} 1... c5 {[%clk 0:02:59....  chessdotcom
#
# [1014585 rows x 13 columns]

# %% [markdown]
# ## Lichess

# %%
files2 = glob.glob('output_data/fact/lichess/moves7/*.parquet')
df_lichess = pd.concat([pd.read_parquet(fp) for fp in files2])

# %%
df_lichess
# Out:
#            game_end_time game_end_date   time_class  white_username  \
# 0    2019-03-02 01:26:12    2019-03-02       bullet      micawber94
# 1    2019-03-02 01:27:59    2019-03-02       bullet  nihalsarin2004
# 2    2019-03-02 01:28:39    2019-03-02  ultraBullet           TOTAL
# 3    2019-03-02 01:30:12    2019-03-02       bullet  nihalsarin2004
# 4    2019-03-02 01:50:03    2019-03-02  ultraBullet            huja
# ..                   ...           ...          ...             ...
# 163  2021-01-05 09:20:06    2021-01-05       bullet      indianstar
# 164  2021-01-05 09:21:47    2021-01-05       bullet  nihalsarin2004
# 165  2021-01-05 09:22:44    2021-01-05       bullet      indianstar
# 166  2021-01-06 02:53:38    2021-01-06       bullet  nihalsarin2004
# 167  2021-01-06 02:55:05    2021-01-06       bullet         MFishka
#
#      white_rating  black_username  black_rating winner termination  \
# 0          2242.0  nihalsarin2004        2616.0  black      resign
# 1          2618.0      HyperBroly        2174.0  white      resign
# 2          1693.0  nihalsarin2004        2103.0  white   outoftime
# 3          2620.0      crankypawn        2157.0  white   outoftime
# 4          1866.0  nihalsarin2004        2079.0  black        mate
# ..            ...             ...           ...    ...         ...
# 163        2806.0  nihalsarin2004        3040.0  white      resign
# 164        3031.0      indianstar        2815.0  white        mate
# 165        2813.0  nihalsarin2004        3033.0  black      resign
# 166        3036.0         MFishka        2837.0  white   outoftime
# 167        2833.0  nihalsarin2004        3039.0  black        mate
#
#                                 opening  \
# 0                        Modern Defense
# 1                         Dutch Defense
# 2                  Van't Kruijs Opening
# 3                      Gedult's Opening
# 4                  King's Indian Attack
# ..                                  ...
# 163                         Indian Game
# 164                   Zukertort Opening
# 165  Zukertort Opening: Pirc Invitation
# 166    Sicilian Defense: Delayed Alapin
# 167       Modern Defense: Standard Line
#
#                                                  moves platform
# 0    d4 g6 c4 Bg7 Nc3 d6 Nf3 Nc6 g3 e5 d5 Nce7 Bg2 ...  lichess
# 1    d4 f5 Nd2 Nf6 Ndf3 g6 g3 Bg7 Bg2 d6 Nh3 O-O O-...  lichess
# 2    e3 d5 f3 Nf6 g3 e6 h3 Bd6 Qe2 h5 f4 h4 g4 Ne4 ...  lichess
# 3    f3 g6 c3 Bg7 Kf2 d6 Ke3 Nf6 Kd3 e5 Kc2 O-O Qe1...  lichess
# 4    Nf3 d5 g3 e6 Bg2 Nf6 O-O Be7 Ne5 O-O Nxf7 Rxf7...  lichess
# ..                                                 ...      ...
# 163  d4 Nf6 Bf4 e6 e3 b6 Nf3 Bb7 Bd3 Bd6 Bg3 O-O Nb...  lichess
# 164  Nf3 Nf6 d3 g6 Nbd2 Bg7 e4 O-O Be2 d6 O-O Nbd7 ...  lichess
# 165  Nf3 d6 d4 g6 c4 Bg7 Nc3 Nc6 e4 Bg4 d5 Nd4 Be3 ...  lichess
# 166  e4 c5 Nf3 d6 c3 Nf6 h3 Nc6 Bd3 e5 Bc2 d5 exd5 ...  lichess
# 167  e4 g6 d4 Bg7 Nc3 c6 f4 d5 e5 Nh6 Nf3 Bg4 h3 Bx...  lichess
#
# [33033 rows x 12 columns]

# %%
df_merged = pd.concat([df_chesscom, df_lichess])

# %%
df_merged.reset_index(inplace=True)

# %%
df_merged
# Out:
#          index        game_end_time game_end_date time_class rated  \
# 0            0  2020-10-08 02:38:27    2020-10-08      blitz  True
# 1            1  2020-10-08 02:45:07    2020-10-08      blitz  True
# 2            2  2020-10-08 02:50:36    2020-10-08      blitz  True
# 3            3  2020-10-08 02:54:29    2020-10-08      blitz  True
# 4            4  2020-10-08 02:55:52    2020-10-08      blitz  True
# ...        ...                  ...           ...        ...   ...
# 1047613    163  2021-01-05 09:20:06    2021-01-05     bullet   NaN
# 1047614    164  2021-01-05 09:21:47    2021-01-05     bullet   NaN
# 1047615    165  2021-01-05 09:22:44    2021-01-05     bullet   NaN
# 1047616    166  2021-01-06 02:53:38    2021-01-06     bullet   NaN
# 1047617    167  2021-01-06 02:55:05    2021-01-06     bullet   NaN
#
#             white_username  white_rating     black_username  black_rating  \
# 0        VitaliyBernadskiy        2788.0   Farrukh_Amonatov        2755.0
# 1         Farrukh_Amonatov        2764.0  VitaliyBernadskiy        2779.0
# 2        VitaliyBernadskiy        2771.0   Farrukh_Amonatov        2772.0
# 3         Farrukh_Amonatov        2780.0  VitaliyBernadskiy        2763.0
# 4                     KD64        2510.0           fyall777        2495.0
# ...                    ...           ...                ...           ...
# 1047613         indianstar        2806.0     nihalsarin2004        3040.0
# 1047614     nihalsarin2004        3031.0         indianstar        2815.0
# 1047615         indianstar        2813.0     nihalsarin2004        3033.0
# 1047616     nihalsarin2004        3036.0            MFishka        2837.0
# 1047617            MFishka        2833.0     nihalsarin2004        3039.0
#
#         winner                          termination  \
# 0        white        VitaliyBernadskiy won on time
# 1        white  Farrukh_Amonatov won by resignation
# 2        black  Farrukh_Amonatov won by resignation
# 3        white  Farrukh_Amonatov won by resignation
# 4        white                     KD64 won on time
# ...        ...                                  ...
# 1047613  white                               resign
# 1047614  white                                 mate
# 1047615  black                               resign
# 1047616  white                            outoftime
# 1047617  black                                 mate
#
#                                                    opening  \
# 0                Sicilian Defense Grand Prix Attack 3...d6
# 1        Scotch Game Classical Variation 5.Be3 Qf6 6.c3...
# 2                    Sicilian Defense Deferred Wing Gambit
# 3        Scotch Game Schmidt Mieses Variation 6...Qe7 7...
# 4            Queens Pawn Opening Accelerated London System
# ...                                                    ...
# 1047613                                        Indian Game
# 1047614                                  Zukertort Opening
# 1047615                 Zukertort Opening: Pirc Invitation
# 1047616                   Sicilian Defense: Delayed Alapin
# 1047617                      Modern Defense: Standard Line
#
#                                                      moves     platform
# 0        1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02:5...  chessdotcom
# 1        1. e4 {[%clk 0:02:59.9]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 2        1. e4 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02:5...  chessdotcom
# 3        1. e4 {[%clk 0:02:59.9]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 4        1. d4 {[%clk 0:02:59.9]} 1... d5 {[%clk 0:02:5...  chessdotcom
# ...                                                    ...          ...
# 1047613  d4 Nf6 Bf4 e6 e3 b6 Nf3 Bb7 Bd3 Bd6 Bg3 O-O Nb...      lichess
# 1047614  Nf3 Nf6 d3 g6 Nbd2 Bg7 e4 O-O Be2 d6 O-O Nbd7 ...      lichess
# 1047615  Nf3 d6 d4 g6 c4 Bg7 Nc3 Nc6 e4 Bg4 d5 Nd4 Be3 ...      lichess
# 1047616  e4 c5 Nf3 d6 c3 Nf6 h3 Nc6 Bd3 e5 Bc2 d5 exd5 ...      lichess
# 1047617  e4 g6 d4 Bg7 Nc3 c6 f4 d5 e5 Nh6 Nf3 Bg4 h3 Bx...      lichess
#
# [1047618 rows x 14 columns]

# %% [markdown]
# ## Compile Openings

# %%
openings_query = """      select
                            opening as opening,
                            sum(case when winner = "white" then 1 else 0 end) as white_wins,
                            sum(case when winner = "black" then 1 else 0 end) as black_wins,
                            count(*) as game_count
                        from df_merged

                        group by opening
                        order by black_wins desc"""

# %%
openings_df = ps.sqldf(openings_query, locals())

# %%
openings_df
# Out:
#                                                 opening  white_wins  \
# 0                                                  None       24938
# 1                                           Indian Game        6272
# 2     English Opening Anglo Indian Kings Knight Vari...        6702
# 3               Queens Pawn Opening Zukertort Variation        5482
# 4                      Queens Gambit Declined 3.Nf3 Nf6        4450
# ...                                                 ...         ...
# 9874     Alekhine Defense: Mokele Mbembe, Vavra Defense           1
# 9875  Alekhine Defense: Modern Variation, Panov Vari...           1
# 9876      Alekhine Defense: Modern Variation, Main Line           1
# 9877  Alekhine Defense: Modern Variation, Alburt Var...           1
# 9878  Alekhine Defense: Hunt Variation, Lasker Simul...           1
#
#       black_wins  game_count
# 0          25554       51059
# 1           6455       14026
# 2           5475       13688
# 3           5052       11655
# 4           4086        9845
# ...          ...         ...
# 9874           0           1
# 9875           0           1
# 9876           0           1
# 9877           0           1
# 9878           0           1
#
# [9879 rows x 4 columns]

# %% [markdown]
# ## Compile Players

# %%
players_query = """ with white_players as (

                    select
                        white_username as username,
                        sum(case when winner = "white" then 1 else 0 end) as white_wins,
                        count(*) as white_games
                    from df_merged

                    group by white_username
                        ),
                        
                    black_players as (
                    
                    select
                        black_username as username,
                        sum(case when winner = "black" then 1 else 0 end) as black_wins,
                        count(*) as black_games
                    from df_merged

                    group by black_username
                    )
                    
                    select
                        white_players.username,
                        white_wins,
                        white_games,
                        cast(white_wins / white_games as float(10,10)) as white_win_perc,
                        black_wins,
                        black_games,
                        cast (black_wins / black_games as float(10)) as black_win_perc
                    from white_players
                    
                    inner join black_players on white_players.username = black_players.username
                    
                    order by white_wins desc
                      """

# %%
players_df = ps.sqldf(players_query, locals())

# %%
players_df
# Out:
#                username  white_wins  white_games  white_win_perc  black_wins  \
# 0      DanielNaroditsky       22617        37959             0.0       21476
# 1          Firouzja2003       12326        21957             0.0       11659
# 2        nihalsarin2004       12326        16519             0.0       11605
# 3            abykhovsky        7923        15534             0.0        7570
# 4            erichansen        7856        13238             0.0        7349
# ...                 ...         ...          ...             ...         ...
# 31056        zwilling67           0            2             0.0           0
# 31057           zwolin1           0            1             0.0           0
# 31058          zwzwzwzw           0            2             0.0           1
# 31059       zyraninman9           0            2             0.0           1
# 31060     zyraninmort12           0            2             0.0           0
#
#        black_games  black_win_perc
# 0            37945             0.0
# 1            21871             0.0
# 2            16514             0.0
# 3            15584             0.0
# 4            13207             0.0
# ...            ...             ...
# 31056            2             0.0
# 31057            1             0.0
# 31058            2             0.0
# 31059            1             1.0
# 31060            1             0.0
#
# [31061 rows x 7 columns]
