# %%
import pandas as pd
import pyarrow
import pandasql as ps
import glob

# %% [markdown]
# ## Chess.com

# %%
files = glob.glob('output_data/fact/chessdotcom/moves6/*.parquet')
df_chesscom = pd.concat([pd.read_parquet(fp) for fp in files])

# %%
#pd.set_option('display.max_rows', None)

# %%
df_chesscom
# Out:
#           game_end_time game_end_date time_class  rated    white_username  \
# 0   2019-04-04 05:06:07    2019-04-04     bullet   True         1stSecond
# 1   2019-04-04 05:07:48    2019-04-04     bullet   True            kpio91
# 2   2019-04-04 05:10:21    2019-04-04     bullet   True         1stSecond
# 3   2019-04-04 05:12:30    2019-04-04     bullet   True            kpio91
# 4   2019-04-04 06:52:07    2019-04-04      blitz   True         1stSecond
# ..                  ...           ...        ...    ...               ...
# 87  2019-11-28 07:02:34    2019-11-28      blitz   True          supreme3
# 88  2019-11-28 07:06:13    2019-11-28      blitz   True          1977Ivan
# 89  2019-11-28 07:11:02    2019-11-28      blitz   True  sofaceindisguise
# 90  2019-11-28 07:15:20    2019-11-28      blitz   True          1977Ivan
# 91  2019-11-28 07:16:32    2019-11-28      blitz   True  sofaceindisguise
#
#     white_rating        black_username  black_rating winner  \
# 0           2743                kpio91          2651  white
# 1           2644             1stSecond          2749  black
# 2           2747                kpio91          2647   None
# 3           2640             1stSecond          2753  black
# 4           2668  ExceptionallyDubious          2692   None
# ..           ...                   ...           ...    ...
# 87          2436              1977Ivan          2631  black
# 88          2666      sofaceindisguise          2632  white
# 89          2625              1977Ivan          2694  black
# 90          2717      sofaceindisguise          2618  white
# 91          2612              1977Ivan          2736  black
#
#                                        termination  \
# 0                     1stSecond won by resignation
# 1                     1stSecond won by resignation
# 2   Game drawn by timeout vs insufficient material
# 3                     1stSecond won by resignation
# 4                          Game drawn by agreement
# ..                                             ...
# 87                     1977Ivan won by resignation
# 88                     1977Ivan won by resignation
# 89                     1977Ivan won by resignation
# 90                     1977Ivan won by resignation
# 91                     1977Ivan won by resignation
#
#                                               opening  \
# 0            Queens Pawn Opening Tartakower Variation
# 1                             Old Benoni Defense 2.d5
# 2                     Queens Pawn Opening 1...c6 2.c4
# 3          Scotch Game Classical Intermezzo Variation
# 4   Reti Opening Reti Gambit Declined Advance Vari...
# ..                                                ...
# 87              Reti Opening Sicilian Invitation 2.g3
# 88      English Opening Reversed Sicilian Closed 3.e3
# 89  Indian Game East Indian Anti Nimzo Indian Vari...
# 90  Queens Gambit Declined Queens Knight Variation...
# 91        Indian Game Spielmann Indian Variation 3.d5
#
#                                                 moves     platform
# 0   1. Nf3 {[%clk 0:00:59.9]} 1... d6 {[%clk 0:00:...  chessdotcom
# 1   1. d4 {[%clk 0:00:59.9]} 1... c5 {[%clk 0:00:5...  chessdotcom
# 2   1. c4 {[%clk 0:00:59.9]} 1... c6 {[%clk 0:00:5...  chessdotcom
# 3   1. e4 {[%clk 0:00:59.9]} 1... e5 {[%clk 0:00:5...  chessdotcom
# 4   1. Nf3 {[%clk 0:02:59.9]} 1... d5 {[%clk 0:02:...  chessdotcom
# ..                                                ...          ...
# 87  1. Nf3 {[%clk 0:02:59.9]} 1... c5 {[%clk 0:02:...  chessdotcom
# 88  1. c4 {[%clk 0:02:59.9]} 1... e5 {[%clk 0:02:5...  chessdotcom
# 89  1. d4 {[%clk 0:02:59.9]} 1... Nf6 {[%clk 0:02:...  chessdotcom
# 90  1. d4 {[%clk 0:02:59.9]} 1... Nf6 {[%clk 0:02:...  chessdotcom
# 91  1. d4 {[%clk 0:02:59.9]} 1... Nf6 {[%clk 0:02:...  chessdotcom
#
# [362303 rows x 13 columns]

# %% [markdown]
# ## Lichess

# %%
files2 = glob.glob('output_data/fact/lichess/moves7/*.parquet')
df_lichess = pd.concat([pd.read_parquet(fp) for fp in files2])

# %%
df_lichess
# Out:
#            game_end_time game_end_date   time_class  white_username  \
# 0    2019-03-02 01:26:12    2019-03-02       bullet      micawber94
# 1    2019-03-02 01:27:59    2019-03-02       bullet  nihalsarin2004
# 2    2019-03-02 01:28:39    2019-03-02  ultraBullet           TOTAL
# 3    2019-03-02 01:30:12    2019-03-02       bullet  nihalsarin2004
# 4    2019-03-02 01:50:03    2019-03-02  ultraBullet            huja
# ..                   ...           ...          ...             ...
# 163  2021-01-05 09:20:06    2021-01-05       bullet      indianstar
# 164  2021-01-05 09:21:47    2021-01-05       bullet  nihalsarin2004
# 165  2021-01-05 09:22:44    2021-01-05       bullet      indianstar
# 166  2021-01-06 02:53:38    2021-01-06       bullet  nihalsarin2004
# 167  2021-01-06 02:55:05    2021-01-06       bullet         MFishka
#
#      white_rating  black_username  black_rating winner termination  \
# 0          2242.0  nihalsarin2004        2616.0  black      resign
# 1          2618.0      HyperBroly        2174.0  white      resign
# 2          1693.0  nihalsarin2004        2103.0  white   outoftime
# 3          2620.0      crankypawn        2157.0  white   outoftime
# 4          1866.0  nihalsarin2004        2079.0  black        mate
# ..            ...             ...           ...    ...         ...
# 163        2806.0  nihalsarin2004        3040.0  white      resign
# 164        3031.0      indianstar        2815.0  white        mate
# 165        2813.0  nihalsarin2004        3033.0  black      resign
# 166        3036.0         MFishka        2837.0  white   outoftime
# 167        2833.0  nihalsarin2004        3039.0  black        mate
#
#                                 opening  \
# 0                        Modern Defense
# 1                         Dutch Defense
# 2                  Van't Kruijs Opening
# 3                      Gedult's Opening
# 4                  King's Indian Attack
# ..                                  ...
# 163                         Indian Game
# 164                   Zukertort Opening
# 165  Zukertort Opening: Pirc Invitation
# 166    Sicilian Defense: Delayed Alapin
# 167       Modern Defense: Standard Line
#
#                                                  moves platform
# 0    d4 g6 c4 Bg7 Nc3 d6 Nf3 Nc6 g3 e5 d5 Nce7 Bg2 ...  lichess
# 1    d4 f5 Nd2 Nf6 Ndf3 g6 g3 Bg7 Bg2 d6 Nh3 O-O O-...  lichess
# 2    e3 d5 f3 Nf6 g3 e6 h3 Bd6 Qe2 h5 f4 h4 g4 Ne4 ...  lichess
# 3    f3 g6 c3 Bg7 Kf2 d6 Ke3 Nf6 Kd3 e5 Kc2 O-O Qe1...  lichess
# 4    Nf3 d5 g3 e6 Bg2 Nf6 O-O Be7 Ne5 O-O Nxf7 Rxf7...  lichess
# ..                                                 ...      ...
# 163  d4 Nf6 Bf4 e6 e3 b6 Nf3 Bb7 Bd3 Bd6 Bg3 O-O Nb...  lichess
# 164  Nf3 Nf6 d3 g6 Nbd2 Bg7 e4 O-O Be2 d6 O-O Nbd7 ...  lichess
# 165  Nf3 d6 d4 g6 c4 Bg7 Nc3 Nc6 e4 Bg4 d5 Nd4 Be3 ...  lichess
# 166  e4 c5 Nf3 d6 c3 Nf6 h3 Nc6 Bd3 e5 Bc2 d5 exd5 ...  lichess
# 167  e4 g6 d4 Bg7 Nc3 c6 f4 d5 e5 Nh6 Nf3 Bg4 h3 Bx...  lichess
#
# [33033 rows x 12 columns]

# %%
df_merged = pd.concat([df_chesscom, df_lichess])

# %%
df_merged.reset_index(inplace=True)

# %%
df_merged
# Out:
#         index        game_end_time game_end_date time_class rated  \
# 0           0  2019-04-04 05:06:07    2019-04-04     bullet  True
# 1           1  2019-04-04 05:07:48    2019-04-04     bullet  True
# 2           2  2019-04-04 05:10:21    2019-04-04     bullet  True
# 3           3  2019-04-04 05:12:30    2019-04-04     bullet  True
# 4           4  2019-04-04 06:52:07    2019-04-04      blitz  True
# ...       ...                  ...           ...        ...   ...
# 395331    163  2021-01-05 09:20:06    2021-01-05     bullet   NaN
# 395332    164  2021-01-05 09:21:47    2021-01-05     bullet   NaN
# 395333    165  2021-01-05 09:22:44    2021-01-05     bullet   NaN
# 395334    166  2021-01-06 02:53:38    2021-01-06     bullet   NaN
# 395335    167  2021-01-06 02:55:05    2021-01-06     bullet   NaN
#
#         white_username  white_rating        black_username  black_rating  \
# 0            1stSecond        2743.0                kpio91        2651.0
# 1               kpio91        2644.0             1stSecond        2749.0
# 2            1stSecond        2747.0                kpio91        2647.0
# 3               kpio91        2640.0             1stSecond        2753.0
# 4            1stSecond        2668.0  ExceptionallyDubious        2692.0
# ...                ...           ...                   ...           ...
# 395331      indianstar        2806.0        nihalsarin2004        3040.0
# 395332  nihalsarin2004        3031.0            indianstar        2815.0
# 395333      indianstar        2813.0        nihalsarin2004        3033.0
# 395334  nihalsarin2004        3036.0               MFishka        2837.0
# 395335         MFishka        2833.0        nihalsarin2004        3039.0
#
#        winner                                     termination  \
# 0       white                    1stSecond won by resignation
# 1       black                    1stSecond won by resignation
# 2        None  Game drawn by timeout vs insufficient material
# 3       black                    1stSecond won by resignation
# 4        None                         Game drawn by agreement
# ...       ...                                             ...
# 395331  white                                          resign
# 395332  white                                            mate
# 395333  black                                          resign
# 395334  white                                       outoftime
# 395335  black                                            mate
#
#                                                   opening  \
# 0                Queens Pawn Opening Tartakower Variation
# 1                                 Old Benoni Defense 2.d5
# 2                         Queens Pawn Opening 1...c6 2.c4
# 3              Scotch Game Classical Intermezzo Variation
# 4       Reti Opening Reti Gambit Declined Advance Vari...
# ...                                                   ...
# 395331                                        Indian Game
# 395332                                  Zukertort Opening
# 395333                 Zukertort Opening: Pirc Invitation
# 395334                   Sicilian Defense: Delayed Alapin
# 395335                      Modern Defense: Standard Line
#
#                                                     moves     platform
# 0       1. Nf3 {[%clk 0:00:59.9]} 1... d6 {[%clk 0:00:...  chessdotcom
# 1       1. d4 {[%clk 0:00:59.9]} 1... c5 {[%clk 0:00:5...  chessdotcom
# 2       1. c4 {[%clk 0:00:59.9]} 1... c6 {[%clk 0:00:5...  chessdotcom
# 3       1. e4 {[%clk 0:00:59.9]} 1... e5 {[%clk 0:00:5...  chessdotcom
# 4       1. Nf3 {[%clk 0:02:59.9]} 1... d5 {[%clk 0:02:...  chessdotcom
# ...                                                   ...          ...
# 395331  d4 Nf6 Bf4 e6 e3 b6 Nf3 Bb7 Bd3 Bd6 Bg3 O-O Nb...      lichess
# 395332  Nf3 Nf6 d3 g6 Nbd2 Bg7 e4 O-O Be2 d6 O-O Nbd7 ...      lichess
# 395333  Nf3 d6 d4 g6 c4 Bg7 Nc3 Nc6 e4 Bg4 d5 Nd4 Be3 ...      lichess
# 395334  e4 c5 Nf3 d6 c3 Nf6 h3 Nc6 Bd3 e5 Bc2 d5 exd5 ...      lichess
# 395335  e4 g6 d4 Bg7 Nc3 c6 f4 d5 e5 Nh6 Nf3 Bg4 h3 Bx...      lichess
#
# [395336 rows x 14 columns]

# %% [markdown]
# ## Compile Openings

# %%
openings_query = """      select
                            opening as opening,
                            sum(case when winner = "white" then 1 else 0 end) as white_wins,
                            sum(case when winner = "black" then 1 else 0 end) as black_wins,
                            count(*) as game_count
                        from df_merged

                        group by opening
                        order by black_wins desc"""

# %%
openings_df = ps.sqldf(openings_query, locals())

# %%
openings_df
# Out:
#                                                 opening  white_wins  \
# 0                                                  None       19744
# 1                                           Indian Game        2365
# 2     English Opening Anglo Indian Kings Knight Vari...        2706
# 3               Queens Pawn Opening Zukertort Variation        1776
# 4                      Queens Gambit Declined 3.Nf3 Nf6        1857
# ...                                                 ...         ...
# 8517     Alekhine Defense: Mokele Mbembe, Vavra Defense           1
# 8518  Alekhine Defense: Modern Variation, Panov Vari...           1
# 8519      Alekhine Defense: Modern Variation, Main Line           1
# 8520  Alekhine Defense: Modern Variation, Alburt Var...           1
# 8521  Alekhine Defense: Hunt Variation, Lasker Simul...           1
#
#       black_wins  game_count
# 0          19793       39884
# 1           2411        5219
# 2           2183        5423
# 3           1702        3854
# 4           1700        4093
# ...          ...         ...
# 8517           0           1
# 8518           0           1
# 8519           0           1
# 8520           0           1
# 8521           0           1
#
# [8522 rows x 4 columns]

# %% [markdown]
# ## Compile Players

# %%
players_query = """ with white_players as (

                    select
                        white_username as username,
                        sum(case when winner = "white" then 1 else 0 end) as white_wins,
                        count(*) as white_games
                    from df_merged

                    group by white_username
                        ),
                        
                    black_players as (
                    
                    select
                        black_username as username,
                        sum(case when winner = "black" then 1 else 0 end) as black_wins,
                        count(*) as black_games
                    from df_merged

                    group by black_username
                    )
                    
                    select
                        white_players.username,
                        white_wins,
                        white_games,
                        cast(white_wins / white_games as float(10,10)) as white_win_perc,
                        black_wins,
                        black_games,
                        cast (black_wins / black_games as float(10)) as black_win_perc
                    from white_players
                    
                    inner join black_players on white_players.username = black_players.username
                    
                    order by white_wins desc
                      """

# %%
players_df = ps.sqldf(players_query, locals())

# %%
players_df
# Out:
#              username  white_wins  white_games  white_win_perc  black_wins  \
# 0      nihalsarin2004       12326        16519             0.0       11605
# 1          abykhovsky        7740        15166             0.0        7409
# 2             aspired        4664         8480             0.0        4607
# 3           1stSecond        3493         6447             0.0        3181
# 4      amintabatabaei        3377         7054             0.0        2949
# ...               ...         ...          ...             ...         ...
# 17522          zuro28           0            1             0.0           1
# 17523          zurzan           0            2             0.0           0
# 17524         zverila           0            1             0.0           0
# 17525      zwilling67           0            2             0.0           0
# 17526         zwolin1           0            1             0.0           0
#
#        black_games  black_win_perc
# 0            16514             0.0
# 1            15220             0.0
# 2             8521             0.0
# 3             6476             0.0
# 4             7051             0.0
# ...            ...             ...
# 17522            1             1.0
# 17523            2             0.0
# 17524            1             0.0
# 17525            2             0.0
# 17526            1             0.0
#
# [17527 rows x 7 columns]
